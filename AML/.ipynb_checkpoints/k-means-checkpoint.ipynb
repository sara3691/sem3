# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans


dataset = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv")
dataset.to_csv("iris2.csv")


x = dataset.drop('species', axis=1).values


kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(x)

cl = kmeans.labels_
ce = kmeans.cluster_centers_
# Plot
plt.figure(figsize=(10,6))
plt.scatter(x[:,0], x[:,1], c=cl, cmap='viridis', s=50)
plt.scatter(ce[:,0], ce[:,1], c='red', marker='X', s=250)
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("K-Means Clustering")
plt.show()
# Out:
# C:\Users\CC-Lab55\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CC-Lab55\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
dataset=pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/refs/heads/master/iris.csv')
x = dataset.drop('species', axis=1).values

kmeans = KMeans(n_clusters=30, random_state=42)
kmeans.fit(x)

cl = kmeans.labels_
ce = kmeans.cluster_centers_

print("Type of X:", type(x), "Shape of X:", x.shape)
print("Type of cl:", type(cl), "Shape of cl:", cl.shape)
print("Type of ce:", type(ce), "Shape of ce:", ce.shape)

plt.figure(figsize=(10, 6))
plt.scatter(x[:, 0], x[:, 1], c=cl, cmap='viridis', label='Data points')
plt.scatter(ce[:, 0], ce[:, 1], c='red', marker='x', s=200, label='Centroids')
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.title("K-Means Clustering")
plt.legend()
plt.show()
# Out:
# C:\Users\CC-Lab55\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\CC-Lab55\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Type of X: <class 'numpy.ndarray'> Shape of X: (150, 4)
# Type of cl: <class 'numpy.ndarray'> Shape of cl: (150,)
# Type of ce: <class 'numpy.ndarray'> Shape of ce: (30, 4)
